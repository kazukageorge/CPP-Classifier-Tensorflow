# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# Visualizing the data

# %%
import pandas as pd
import sys, os
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

#get the directory of the data
pwd = os.path.dirname(os.getcwd())
df = pd.read_csv(pwd +  "/InputData/dataframe/aux.csv")
df =df.drop(['trackNum','catIdx'],1)

# %%
# visualize features vs aux
for col in df:
    plt.figure()
    plt.scatter( df[col],df['aux'])
    plt.ylabel('Aux')
    plt.xlabel(col)
    plt.show()

# %%
#scatter plot of feature vs aux
scatter_matrix(df, figsize = [20,20])
# Out:
# array([[<AxesSubplot:xlabel='lifetime', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='background', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='aux', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='lifetime'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='lifetime'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='background', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='aux', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='max_intensity'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='max_intensity'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='background'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='background'>,
#         <AxesSubplot:xlabel='background', ylabel='background'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='background'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='background'>,
#         <AxesSubplot:xlabel='aux', ylabel='background'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='background'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='background'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='background'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='background'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='background'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='background'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='background', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='aux', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='totaldisp'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='totaldisp'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='background', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='aux', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='max_msd'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='max_msd'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='aux'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='aux'>,
#         <AxesSubplot:xlabel='background', ylabel='aux'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='aux'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='aux'>,
#         <AxesSubplot:xlabel='aux', ylabel='aux'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='aux'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='aux'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='aux'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='aux'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='aux'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='aux'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='background', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='aux', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='avg_rise'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='avg_rise'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='background', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='aux', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='avg_dec'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='avg_dec'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='background', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='aux', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='risevsdec'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='risevsdec'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='background', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='aux', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='avg_mom_rise'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='avg_mom_rise'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='background', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='aux', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='avg_mom_dec'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='avg_mom_dec'>],
#        [<AxesSubplot:xlabel='lifetime', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='max_intensity', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='background', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='totaldisp', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='max_msd', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='aux', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='avg_rise', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='avg_dec', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='risevsdec', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='avg_mom_rise', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='avg_mom_dec', ylabel='risevsdec_mom'>,
#         <AxesSubplot:xlabel='risevsdec_mom', ylabel='risevsdec_mom'>]],
#       dtype=object)
