# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# Visualizing the data

# %%
import pandas as pd
import sys, os

#get the directory of the data

pwd = os.path.dirname(os.getcwd())
print(pwd)
# Out:
# /Users/g

# %%
os.getcwd()
# Out:
# '/Users/g/Documents/GitHub'

# %%
d = os.path.dirname(os.getcwd())

# %%
d
# Out:
# '/Users/g'
